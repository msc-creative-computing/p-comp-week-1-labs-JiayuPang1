# %%
#print ("hello world")
# Out:
# hello world

# %% [markdown]
# ## Hi, this is my first notebook!

# %%
b = str.maketrans("12345","abcde")
print ("11143253".translate(b))
# Out:
# aaadcbec

# %%
map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jn/950rjqrn7yg6vx3xd4tf4jmw0000gn/T/ipykernel_25840/1521430198.py in <module>
# ----> 1 decipher("map")
#
# NameError: name 'decipher' is not defined

# %%
b = str.maketrans("abcdefghijklmnopqrstuvwxyz","zabcdefghijklmnopqrstuvwxy")
print ("The challenge is simple, right? The solution is the same as the second level of the python challenge. But what I want to remind everyone here is that there are many differences and incompatibilities between python3 and python, for example, str.maketrans() and str.translate() can be used directly without from string import maketrans. Go and explore for yourself!".translate(b))
# Out:
# Tgd bgzkkdmfd hr rhlokd, qhfgs? Tgd rnktshnm hr sgd rzld zr sgd rdbnmc kdudk ne sgd oxsgnm bgzkkdmfd. Bts vgzs I vzms sn qdlhmc dudqxnmd gdqd hr sgzs sgdqd zqd lzmx cheedqdmbdr zmc hmbnlozshahkhshdr adsvddm oxsgnm3 zmc oxsgnm, enq dwzlokd, rsq.lzjdsqzmr() zmc rsq.sqzmrkzsd() bzm ad trdc chqdbskx vhsgnts eqnl rsqhmf hlonqs lzjdsqzmr. Gn zmc dwoknqd enq xntqrdke!

# %% [markdown]
# # Libraries
# ## matplotlib

# %%
import matplotlib.pyplot as plt
import math

x = range(100)
y = []

for value in x:
    y.append(value*0.1)

plt.plot(y)

# %% [markdown]
# ## urllib

# %%
import urllib.request

html = urllib.request.urlopen('https://www.arts.ac.uk').read()
print(html)
# Out:
# b'\n\n\n\n \n\n\n\n<!DOCTYPE html>\n\n<html lang="en" itemscope itemtype="https://schema.org/WebPage">\n    \n<head>\n        \r\n<title>University of the Arts London</title>\r\n\r\n<link rel="canonical" href="https://www.arts.ac.uk/" />\r\n\r\n<!-- Misc Metadata -->\r\n<meta charset="utf-8">\r\n<meta name="apple-mobile-web-app-capable" content="yes">\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=3.0, minimum-scale=1.0">\r\n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n\r\n<!-- Global Default Metadata -->\r\n<meta name="dcterms.title"      content="UAL">\r\n<meta name="dcterms.creator"    content="UAL">\r\n<meta name="dcterms.created"    content="2018-01-20T21:02:21+00:00">\r\n<meta name="dcterms.modified"   content="2020-08-06T16:34:27+01:00">\r\n<meta name="dcterms.issued"     content="2020-03-20T14:00:17+00:00">\r\n<meta name="dcterms.format"     content="HTML">\r\n<meta name="dcterms.identifier" content="https://www.arts.ac.
# ...

# %% [markdown]
# ## bokeh

# %%
from bokeh.plotting import figure, output_file, show

# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
output_file("lines.html")

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend="Temp.", line_width=2)

# show the results
show(p)
